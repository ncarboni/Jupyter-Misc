# %% [markdown]
# # Artlas Merging

# %%
import os
import pandas as pd
import warnings
import glob

# %%
keep_col = ["Nom artiste","user","Exposition","Prénom artiste","Sexe artiste (F/M/FM/vide)","Appartenance à un groupe","Éléments biographiques","Adresse complète de l'artiste telle qu'elle apparaît dans le catalogue","Pays de l'artiste","État de l'artiste","Ville de l'artiste","Identifiant WikiData ville de l'artiste","Coordonnées ville de l'artiste","N adresse de l'artiste","Voie adresse de l'artiste","Complément d'adresse de l'artiste","Adresse complète de l'artiste 2 telle qu'elle apparaît dans le catalogue","Pays de l'artiste 2","État de l'artiste 2","Ville de l'artiste 2","Identifiant WikiData ville de l'artiste 2","Coordonnées ville de l'artiste 2","N adresse de l'artiste 2","Voie adresse de l'artiste 2","Complément d'adresse de l'artiste 2","Nationalité artiste","Élève de","Année de naissance","Adresse complète de naissance telle qu'elle apparaît dans le catalogue","Pays de naissance","État de naissance","Ville de naissance","Identifiant WikiData ville de naissance","Coordonnées ville de naissance","Année de mort","Adresse complète de mort telle qu'elle apparaît dans le catalogue","Pays de mort","État de mort","Ville de mort","Identifiant WikiData ville de mort","Coordonnées ville de mort","numéro","Titre oeuvre","Sous-titre","Traduction titre","Année de début de conception","Mois de début de conception","Jour de début de conception","Année de fin de conception","Mois de fin de conception","Jour de fin de conception","Pays de conception","État de conception","Ville de conception","Identifiant WikiData ville de conception","Coordonnées ville de conception","Dimensions","Catégories","Medium","Salle","Chapitre du catalogue","reproduit dans catalogue ?","Prix","Localisation / Propriétaire","Pays du propriétaire","État du propriétaire","Ville du propriétaire","Identifiant WikiData ville du propriétaire","Coordonnées ville du propriétaire","Notes"]

# %%
a1934 = pd.read_csv("/Users/carboni/Downloads/artlas/Paris_Independants_1934.csv", dtype=object)
a1926 = pd.read_csv("/Users/carboni/Downloads/artlas/Paris_Independants_1926.csv", dtype=object)
a1928 = pd.read_csv("/Users/carboni/Downloads/artlas/Paris_Independants_1928.csv", dtype=object)
a1927 = pd.read_csv("/Users/carboni/Downloads/artlas/Paris_Independants_1927.csv", dtype=object)
a1922 = pd.read_csv("/Users/carboni/Downloads/artlas/Paris_Independants_1922.csv", dtype=object)
a1909 = pd.read_csv("/Users/carboni/Downloads/artlas/Paris_Independants_1909.csv", dtype=object)
a1890 = pd.read_csv("/Users/carboni/Downloads/artlas/Paris_Independants_1890.csv", dtype=object)
a1906 = pd.read_csv("/Users/carboni/Downloads/artlas/Paris_Independants_1906.csv", dtype=object)
a1932 = pd.read_csv("/Users/carboni/Downloads/artlas/Paris_Independants_1932.csv", dtype=object)

# %%
a1909.drop(['4'],axis=1,inplace=True)

# %%
a1928.drop(['Unnamed: 2'],axis=1,inplace=True)

# %%
a1932.drop(['Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81','Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89'],axis=1,inplace=True)

# %%
a1926.drop(['Unnamed: 70','Unnamed: 72', 'Unnamed: 71', 'Unnamed: 73', 'Unnamed: 74' ],axis=1,inplace=True)

# %%
spike_cols = [col for col in a1909.columns if '4' in col]
print(spike_cols)
# Out:
# ['4']

# %%
frames = [a1934, a1926, a1928, a1927, a1922, a1909, a1890, a1906, a1932]

# %%
df = pd.concat(frames, ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32574 entries, 0 to 32573
# Data columns (total 76 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Nom artiste                                                               32555 non-null  object
#  1   user                                                                      24121 non-null  object
#  2   Exposition                                                                20100 non-null  object
#  3   Prénom artiste                                                            31950 non-null  object
#  4   Sexe artiste (F/M/FM/vide)                                                32395 non-null  object
#  5   Appartenance à un groupe                                                  4186 non-null   object
#  6   Éléments biographiques                                                    31950 non-null  object
#  7   Adresse complète de l'artiste telle qu'elle apparaît dans le catalogue    32198 non-null  object
#  8   Pays de l'artiste                                                         27923 non-null  object
#  9   État de l'artiste                                                         16231 non-null  object
#  10  Ville de l'artiste                                                        31837 non-null  object
#  11  Identifiant WikiData ville de l'artiste                                   27850 non-null  object
#  12  Coordonnées ville de l'artiste                                            27510 non-null  object
#  13  N adresse de l'artiste                                                    30027 non-null  object
#  14  Voie adresse de l'artiste                                                 30692 non-null  object
#  15  Complément d'adresse de l'artiste                                         24211 non-null  object
#  16  Adresse complète de l'artiste 2 telle qu'elle apparaît dans le catalogue  17887 non-null  object
#  17  Pays de l'artiste 2                                                       21989 non-null  object
#  18  État de l'artiste 2                                                       21907 non-null  object
#  19  Ville de l'artiste 2                                                      16556 non-null  object
#  20  Identifiant WikiData ville de l'artiste 2                                 248 non-null    object
#  21  Coordonnées ville de l'artiste 2                                          4136 non-null   object
#  22  N adresse de l'artiste 2                                                  21750 non-null  object
#  23  Voie adresse de l'artiste 2                                               21750 non-null  object
#  24  Complément d'adresse de l'artiste 2                                       21957 non-null  object
#  25  Nationalité artiste                                                       23182 non-null  object
#  26  Élève de                                                                  21931 non-null  object
#  27  Année de naissance                                                        14110 non-null  object
#  28  Adresse complète de naissance telle qu'elle apparaît dans le catalogue    23828 non-null  object
#  29  Pays de naissance                                                         27582 non-null  object
#  30  État de naissance                                                         16571 non-null  object
#  31  Ville de naissance                                                        31092 non-null  object
#  32  Identifiant WikiData ville de naissance                                   22896 non-null  object
#  33  Coordonnées ville de naissance                                            30545 non-null  object
#  34  Année de mort                                                             17445 non-null  object
#  35  Adresse complète de mort telle qu'elle apparaît dans le catalogue         21949 non-null  object
#  36  Pays de mort                                                              21949 non-null  object
#  37  État de mort                                                              21931 non-null  object
#  38  Ville de mort                                                             21949 non-null  object
#  39  Identifiant WikiData ville de mort                                        61 non-null     object
#  40  Coordonnées ville de mort                                                 61 non-null     object
#  41  numéro                                                                    32555 non-null  object
#  42  Titre oeuvre                                                              32450 non-null  object
#  43  Sous-titre                                                                5935 non-null   object
#  44  Traduction titre                                                          9725 non-null   object
#  45  Année de début de conception                                              21807 non-null  object
#  46  Mois de début de conception                                               21894 non-null  object
#  47  Jour de début de conception                                               21907 non-null  object
#  48  Année de fin de conception                                                21911 non-null  object
#  49  Mois de fin de conception                                                 21919 non-null  object
#  50  Jour de fin de conception                                                 21922 non-null  object
#  51  Pays de conception                                                        21927 non-null  object
#  52  État de conception                                                        21928 non-null  object
#  53  Ville de conception                                                       21927 non-null  object
#  54  Identifiant WikiData ville de conception                                  0 non-null      object
#  55  Coordonnées ville de conception                                           0 non-null      object
#  56  Dimensions                                                                25950 non-null  object
#  57  Catégories                                                                26642 non-null  object
#  58  Medium                                                                    26364 non-null  object
#  59  Salle                                                                     21931 non-null  object
#  60  Chapitre du catalogue                                                     21931 non-null  object
#  61  reproduit dans catalogue ?                                                18952 non-null  object
#  62  Prix                                                                      23803 non-null  object
#  63  Localisation / Propriétaire                                               18090 non-null  object
#  64  Pays du propriétaire                                                      17381 non-null  object
#  65  État du propriétaire                                                      25952 non-null  object
#  66  Ville du propriétaire                                                     17817 non-null  object
#  67  Identifiant WikiData ville du propriétaire                                0 non-null      object
#  68  Coordonnées ville du propriétaire                                         0 non-null      object
#  69  Notes                                                                     4465 non-null   object
#  70  4                                                                         8091 non-null   object
#  71  Coordonnées ville de naissance.1                                          3980 non-null   object
#  72  Coordonnées ville de l'artiste.1                                          3979 non-null   object
#  73  Coordonnées ville de l'artiste.2                                          3979 non-null   object
#  74  Coordonnées ville de naissance.2                                          3272 non-null   object
#  75  Coordonnées ville de naissance.3                                          3272 non-null   object
# dtypes: object(76)
# memory usage: 18.9+ MB

# %%
df.head()
# Out:
#   Nom artiste      user                                         Exposition  \
# 0       ABBAL  disanto7  Exposition du cinquantenaire de la Société des...
# 1       ABBAL  disanto7  Exposition du cinquantenaire de la Société des...
# 2   ABONDANCE  disanto7  Exposition du cinquantenaire de la Société des...
# 3   ABONDANCE  disanto7  Exposition du cinquantenaire de la Société des...
# 4        ABOU  disanto7  Exposition du cinquantenaire de la Société des...
#
#   Prénom artiste Sexe artiste (F/M/FM/vide) Appartenance à un groupe  \
# 0          André                          M
# 1          André                          M
# 2        Maurice                          M
# 3        Maurice                          M
# 4      Albert-H.                          M
#
#           Éléments biographiques  \
# 0  1920. né à Moissac (T.-et-G.)
# 1  1920. né à Moissac (T.-et-G.)
# 2                né à Paris 1934
# 3                né à Paris 1934
# 4            1929 né à Marseille
#
#   Adresse complète de l'artiste telle qu'elle apparaît dans le catalogue  \
# 0                                 6, voie Brune, 14e
# 1                                 6, voie Brune, 14e
# 2                 21, avenue du Parc-Montsouris, 14e
# 3                 21, avenue du Parc-Montsouris, 14e
# 4                               10, villa Duthy, 14e
#
#   Pays de l'artiste État de l'artiste  ...  \
# 0            France                    ...
# 1            France                    ...
# 2            France                    ...
# 3            France                    ...
# 4            France                    ...
#
#   Identifiant WikiData ville du propriétaire  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Coordonnées ville du propriétaire  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#                                                Notes Unnamed: 2    4  \
# 0  La date donnée pour tous les artistes, sans ex...        NaN  NaN
# 1  La date donnée pour tous les artistes, sans ex...        NaN  NaN
# 2  La date donnée pour tous les artistes, sans ex...        NaN  NaN
# 3  La date donnée pour tous les artistes, sans ex...        NaN  NaN
# 4  La date donnée pour tous les artistes, sans ex...        NaN  NaN
#
#   Coordonnées ville de naissance.1 Coordonnées ville de l'artiste.1  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#   Coordonnées ville de l'artiste.2 Coordonnées ville de naissance.2  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#   Coordonnées ville de naissance.3
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
# [5 rows x 77 columns]

# %%
df.to_csv('/Users/carboni/Downloads/artlas/combined.csv', index=False)
