# %% [markdown]
# # Filter dataframe by column value

# %% [markdown]
# filter by "Shanghai" as City

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/carboni/Downloads/cluster_160.csv")

# %%
df.head(3)
# Out:
#                                       numero_cluster  manifest_url  \
# 0  000fd000cc8ea527071a7142305b68cf69cf7436de747c...           NaN
# 1  000fd000cc8ea527071a7142305b68cf69cf7436de747c...           NaN
# 2  000fd000cc8ea527071a7142305b68cf69cf7436de747c...           NaN
#
#    canvas_number                                          image_url    City  \
# 0            105  https://digi.ub.uni-heidelberg.de/iiif/2/studi...  London
# 1            271  https://digi.ub.uni-heidelberg.de/iiif/2/revue...   Paris
# 2             10  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k54...   Paris
#
#           Country                               Title  \
# 0  United Kingdom          Studio : international art
# 1          France      Revue des beaux-arts de France
# 2          France  Le Rideau artistique et littéraire
#
#                                       wkt        Date        Journal Type  \
# 0          POINT(-0.1275 51.507222222222)  1900-01-01  Modern Art Journal
# ...

# %%
df2 = df[df['City'].notnull()]

# %%
df3 = df2[df2['City'].str.contains("Shanghai")]

# %%
df3.head()
# Out:
#                                           numero_cluster  manifest_url  \
# 6154   0008e9007f042bc3081c5ce78362b794809f86356c036c...           NaN
# 26560  00008a00db7aafbae397c588b5b81e358799012c29a29e...           NaN
# 26561  00008a00db7aafbae397c588b5b81e358799012c29a29e...           NaN
# 26562  00008a00db7aafbae397c588b5b81e358799012c29a29e...           NaN
# 26563  00008a00db7aafbae397c588b5b81e358799012c29a29e...           NaN
#
#        canvas_number                                          image_url  \
# 6154              43  https://iiif.unige.ch/iiif/2/fedora_ug8056314;...
# 26560             14  https://iiif.unige.ch/iiif/2/fedora_ug8049210;...
# 26561             16  https://iiif.unige.ch/iiif/2/fedora_ug8101934;...
# 26562             16  https://iiif.unige.ch/iiif/2/fedora_ug8102695;...
# 26563              2  https://iiif.unige.ch/iiif/2/fedora_ug8051362;...
#
#            City                     Country              Title  \
# ...

# %%
df3.to_csv("Shanghai_160.csv")
