# %%
import os
import pandas as pd
import warnings
import glob

# %%
path = r'/Users/carboni/Downloads/style' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0, delimiter=',')
    li.append(df)

df2 = pd.concat(li, axis=0, ignore_index=True)

# %%
df2
# Out:
#                                         numero_cluster  \
# 0    00000b00fe4157fe9922dae53a6d206a9b107752753e77...
# 1    00000b00fe4157fe9922dae53a6d206a9b107752753e77...
# 2    00000b00fe4157fe9922dae53a6d206a9b107752753e77...
# 3    00000b00fe4157fe9922dae53a6d206a9b107752753e77...
# 4    00000b00fe4157fe9922dae53a6d206a9b107752753e77...
# ..                                                 ...
# 201  000003008da7a2abfbbd1825d49994b9de0cddcf98f21c...
# 202  000003008da7a2abfbbd1825d49994b9de0cddcf98f21c...
# 203  0000030036e83e46e88de655a647206de35d0b2f21f3b7...
# 204  0000030036e83e46e88de655a647206de35d0b2f21f3b7...
# 205  0000030036e83e46e88de655a647206de35d0b2f21f3b7...
#
#                                           manifest_url  canvas_number  \
# 0    https://digi.ub.uni-heidelberg.de/diglit/iiif/...            540
# 1    https://bluemountain.princeton.edu/bluemtn/iii...             18
# 2    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...            156
# 3    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...            193
# 4    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...            212
# ..                                                 ...            ...
# 201  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k97...            404
# 202  https://iiif.unige.ch/dhportal/ug8001690/manifest             38
# 203  https://digi.ub.uni-heidelberg.de/diglit/iiif/...            282
# 204  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k10...            172
# 205  https://iiif.unige.ch/dhportal/ug8014414/manifest              5
#
#                                              image_url           City  \
# 0    https://digi.ub.uni-heidelberg.de/iiif/2/cicer...        Leipzig
# 1    https://bluemountain.princeton.edu/bluemtn/iii...         Prague
# 2    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...          Paris
# 3    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...          Paris
# 4    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...          Paris
# ..                                                 ...            ...
# 201  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k97...          Paris
# 202  https://iiif.unige.ch/iiif/2/fedora_ug8049470;...  New York City
# 203  https://digi.ub.uni-heidelberg.de/iiif/2/cicer...        Leipzig
# 204  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k10...          Paris
# 205  https://iiif.unige.ch/iiif/2/fedora_ug8099142;...         Warsaw
#
#                       Country                           Title  \
# 0                     Germany                    Der Cicerone
# 1              Czech Republic                     Volné směry
# 2                      France         L'Amour de l'art (1920)
# 3                      France         L'Amour de l'art (1920)
# 4                      France           Cahiers d'art (Paris)
# ..                        ...                             ...
# 201                    France           Cahiers d'art (Paris)
# 202  United States of America                     Camera Work
# 203                   Germany                    Der Cicerone
# 204                    France  L'Esprit nouveau (Paris. 1920)
# 205                    Poland                            Blok
#
#                                         wkt        Date         Journal Type  \
# 0                       POINT(12.375 51.34)  1928-01-01   Modern Art Journal
# 1    POINT(14.416666666667 50.083333333333)  1900-01-01          Art Journal
# 2    POINT(2.3513888888889 48.856944444444)  1947-01-01   Modern Art Journal
# 3    POINT(2.3513888888889 48.856944444444)  1932-01-01   Modern Art Journal
# 4    POINT(2.3513888888889 48.856944444444)  1931-01-01   Modern Art Journal
# ..                                      ...         ...                  ...
# 201  POINT(2.3513888888889 48.856944444444)  1927-01-01   Modern Art Journal
# 202             POINT(-74.006015 40.712728)  1912-08-01          Photography
# 203                     POINT(12.375 51.34)  1930-01-01   Modern Art Journal
# 204  POINT(2.3513888888889 48.856944444444)  1924-01-01  Avant-garde Journal
# 205         POINT(21.011111111111113 52.23)  1924-06-01  Avant-garde Journal
#
#      notice
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 201     NaN
# 202     NaN
# 203     NaN
# 204     NaN
# 205     NaN
#
# [206 rows x 11 columns]

# %%
df2.to_csv('/Users/carboni/Downloads/exhibitions/combined.csv', index=False)

# %% [markdown]
# ### Concat existing dataframe

# %%
df1 = pd.read_csv("/Users/carboni/Downloads/style/cubism.csv")

# %%
df2 = pd.read_csv("/Users/carboni/Downloads/style/impressionism.csv")

# %%
df1["style"] = "cubism"

# %%
df2["style"] = "impressionism"

# %%
df_merged = df1.append(df2, ignore_index=True)
# Out:
# /var/folders/nw/zm4zl9xn4_d_rq3fnglst3n80000gp/T/ipykernel_38087/95201270.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_merged = df1.append(df2, ignore_index=True)

# %%
df_merged
# Out:
#                                         numero_cluster  \
# 0    00000600450b9b20140bc717ab7e849bad10e18e0a818f...
# 1    00000600450b9b20140bc717ab7e849bad10e18e0a818f...
# 2    00000600450b9b20140bc717ab7e849bad10e18e0a818f...
# 3    00000600450b9b20140bc717ab7e849bad10e18e0a818f...
# 4    00000600450b9b20140bc717ab7e849bad10e18e0a818f...
# ..                                                 ...
# 201  000003006a2c100b11ae722d5fd67b6a89e8277f3c0051...
# 202  000003006a2c100b11ae722d5fd67b6a89e8277f3c0051...
# 203  000003003bf66b7b8674c1717203feeb49c79e4701aac0...
# 204  000003003bf66b7b8674c1717203feeb49c79e4701aac0...
# 205  000003003bf66b7b8674c1717203feeb49c79e4701aac0...
#
#                                           manifest_url  canvas_number  \
# 0    https://digi.ub.uni-heidelberg.de/diglit/iiif/...            311
# 1    https://digi.ub.uni-heidelberg.de/diglit/iiif/...            530
# 2    https://digi.ub.uni-heidelberg.de/diglit/iiif/...            793
# 3    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k97...            189
# 4    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k97...            298
# ..                                                 ...            ...
# 201  https://digi.ub.uni-heidelberg.de/diglit/iiif/...            114
# 202  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k61...             86
# 203  https://digi.ub.uni-heidelberg.de/diglit/iiif/...              9
# 204  https://digi.ub.uni-heidelberg.de/diglit/iiif/...             25
# 205  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...            293
#
#                                              image_url           City  \
# 0    https://digi.ub.uni-heidelberg.de/iiif/2/dkd19...      Stuttgart
# 1    https://digi.ub.uni-heidelberg.de/iiif/2/cicer...        Leipzig
# 2    https://digi.ub.uni-heidelberg.de/iiif/2/cicer...        Leipzig
# 3    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k97...          Paris
# 4    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k97...          Paris
# ..                                                 ...            ...
# 201  https://digi.ub.uni-heidelberg.de/iiif/2/inter...  New York City
# 202  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k61...          Paris
# 203  https://digi.ub.uni-heidelberg.de/iiif/2/studi...         London
# 204  https://digi.ub.uni-heidelberg.de/iiif/2/inter...  New York City
# 205  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...          Paris
#
#                       Country                          Title  \
# 0                     Germany  Deutsche Kunst und Dekoration
# 1                     Germany                   Der Cicerone
# 2                     Germany                   Der Cicerone
# 3                      France          Cahiers d'art (Paris)
# 4                      France          Cahiers d'art (Paris)
# ..                        ...                            ...
# 201  United States of America           International studio
# 202                    France          L'Art et les artistes
# 203            United Kingdom     Studio : international art
# 204  United States of America           International studio
# 205                    France        L'Amour de l'art (1920)
#
#                                         wkt        Date        Journal Type  \
# 0             POINT(9.1775 48.776111111111)  1932-01-01      Decorative Art
# 1                       POINT(12.375 51.34)  1927-01-01  Modern Art Journal
# 2                       POINT(12.375 51.34)  1926-01-01  Modern Art Journal
# 3    POINT(2.3513888888889 48.856944444444)  1932-01-01  Modern Art Journal
# 4    POINT(2.3513888888889 48.856944444444)  1930-01-01  Modern Art Journal
# ..                                      ...         ...                 ...
# 201             POINT(-74.006015 40.712728)  1908-01-01  Modern Art Journal
# 202  POINT(2.3513888888889 48.856944444444)  1920-10-01         Art Journal
# 203          POINT(-0.1275 51.507222222222)  1915-01-01  Modern Art Journal
# 204             POINT(-74.006015 40.712728)  1914-01-01  Modern Art Journal
# 205  POINT(2.3513888888889 48.856944444444)  1931-01-01  Modern Art Journal
#
#      notice          style
# 0       NaN         cubism
# 1       NaN         cubism
# 2       NaN         cubism
# 3       NaN         cubism
# 4       NaN         cubism
# ..      ...            ...
# 201     NaN  impressionism
# 202     NaN  impressionism
# 203     NaN  impressionism
# 204     NaN  impressionism
# 205     NaN  impressionism
#
# [206 rows x 12 columns]

# %%
df_merged.to_csv('/Users/carboni/Downloads/exhibitions/combined.csv', index=False)
