# %%
import time
import os
import pandas as pd

# %% [markdown]
# # Delete LOC

# %%
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2389835078380
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 1682513277847
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 1846991909112
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2175923304460
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2549184439302
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 1757514782790
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2076294752725
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2109241765060
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2122727229915
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2483313338248
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2041942922787
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 1843210601193
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 1791733180427
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2200801962996
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2341398802379
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2147827240199
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2317381387904
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 1828758837481
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2179935049122
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2021378478585
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2617580246223
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2445590155408
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 1912292733228
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2446154858681
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2357471319062
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2249190553898
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2040391463794
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 1705312034019
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2365660000326
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 1855950114836
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2077583281405
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2517317880741
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2515668276483
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2014194935307
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 1733887448578
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2030557694971
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2552926249414
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2515355728794
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 1764339010948
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2600552077868
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 2532188477292
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --delete 1738347069183
# Out:
# Project 2389835078380 has been successfully deleted
# Project 1682513277847 has been successfully deleted
# Project 1846991909112 has been successfully deleted
# Project 2175923304460 has been successfully deleted
# Project 2549184439302 has been successfully deleted
# Project 1757514782790 has been successfully deleted
# Project 2076294752725 has been successfully deleted
# Project 2109241765060 has been successfully deleted
# Project 2122727229915 has been successfully deleted
# Project 2483313338248 has been successfully deleted
# Project 2041942922787 has been successfully deleted
# Project 1843210601193 has been successfully deleted
# Project 1791733180427 has been successfully deleted
# Project 2200801962996 has been successfully deleted
# Project 2341398802379 has been successfully deleted
# Project 2147827240199 has been successfully deleted
# Project 2317381387904 has been successfully deleted
# Project 1828758837481 has been successfully deleted
# ...

# %% [markdown]
# # Split LOC

# %%
source_path = "/Users/carboni/Documents/UNIGE/pynotebook/OpenRefine_fusion/backup/LOC_type.csv"
keep_col = ['Media URL','City','Country','wkt', 'normalized_date', 'Title', 'Journal Type']
for i,chunk in enumerate(pd.read_csv(source_path, chunksize=77000)):
    chunk = chunk[keep_col]
    chunk.to_csv('/Users/carboni/Downloads/LOC-split/LOC_data_split_{}.csv'.format(i), index=False)

# %% [markdown]
# # Upload LOC

# %%
path = '/Users/carboni/Downloads/LOC-split/'
os.chdir(path)

# %%
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_0.csv --projectName=LOC_data_split_0
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_14.csv --projectName=LOC_data_split_14
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_2.csv --projectName=LOC_data_split_2
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_25.csv --projectName=LOC_data_split_25
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_30.csv --projectName=LOC_data_split_30
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_36.csv --projectName=LOC_data_split_36
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_6.csv --projectName=LOC_data_split_6
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_1.csv --projectName=LOC_data_split_1
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_15.csv --projectName=LOC_data_split_15
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_20.csv --projectName=LOC_data_split_20
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_26.csv --projectName=LOC_data_split_26
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_31.csv --projectName=LOC_data_split_31
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_37.csv --projectName=LOC_data_split_37
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_7.csv --projectName=LOC_data_split_7
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_10.csv --projectName=LOC_data_split_10
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_16.csv --projectName=LOC_data_split_16
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_21.csv --projectName=LOC_data_split_21
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_27.csv --projectName=LOC_data_split_27
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_32.csv --projectName=LOC_data_split_32
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_38.csv --projectName=LOC_data_split_38
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_8.csv --projectName=LOC_data_split_8
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_11.csv --projectName=LOC_data_split_11
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_17.csv --projectName=LOC_data_split_17
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_22.csv --projectName=LOC_data_split_22
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_28.csv --projectName=LOC_data_split_28
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_33.csv --projectName=LOC_data_split_33
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_39.csv --projectName=LOC_data_split_39
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_9.csv --projectName=LOC_data_split_9
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_12.csv --projectName=LOC_data_split_12
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_18.csv --projectName=LOC_data_split_18
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_23.csv --projectName=LOC_data_split_23
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_29.csv --projectName=LOC_data_split_29
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_34.csv --projectName=LOC_data_split_34
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_4.csv --projectName=LOC_data_split_4
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_13.csv --projectName=LOC_data_split_13
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_19.csv --projectName=LOC_data_split_19
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_24.csv --projectName=LOC_data_split_24
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_3.csv --projectName=LOC_data_split_3
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_35.csv --projectName=LOC_data_split_35
print("sleeping...")
time.sleep(60)
print("awake")
# !docker run --rm --platform linux/amd64 --network=host -v ${PWD}:/data:z felixlohmeier/openrefine-client:v0.3.10 --host 129.194.213.75 -P 80 --create LOC_data_split_5.csv --projectName=LOC_data_split_5
# Out:
# id: 1925587793374
# rows: 77000
# sleeping...
# awake
# id: 2538385635662
# rows: 77000
# sleeping...
# awake
# id: 2333144205275
# rows: 77000
# sleeping...
# awake
# id: 1687001451701
# rows: 77000
# sleeping...
# awake
# id: 2219437066303
# rows: 77000
# sleeping...
# awake
# id: 2273346668343
# rows: 77000
# sleeping...
# awake
# id: 2282051206740
# rows: 77000
# sleeping...
# awake
# id: 2028244303928
# rows: 77000
# sleeping...
# awake
# id: 2491440782735
# rows: 77000
# sleeping...
# awake
# id: 2042428570357
# rows: 77000
# sleeping...
# awake
# id: 2280248021033
# rows: 77000
# sleeping...
# awake
# id: 2189152144933
# rows: 77000
# sleeping...
# awake
# id: 2101887052824
# rows: 77000
# sleeping...
# awake
# id: 2358131718020
# rows: 77000
# sleeping...
# awake
# id: 1674978462904
# rows: 77000
# sleeping...
# awake
# id: 1699392146713
# rows: 77000
# sleeping...
# awake
# id: 2576032583896
# rows: 77000
# sleeping...
# awake
# id: 1669216107142
# rows: 77000
# sleeping...
# ...
