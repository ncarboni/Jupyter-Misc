# %%
from keplergl import KeplerGl
import pandas as pd

# %%
df = pd.read_csv('/Users/carboni/Downloads/cluster_art.csv')

# %%
df.head()
# Out:
#                                       numero_cluster  \
# 0  000015000efde4fb565ecce428ffa0bec31879c1666321...
# 1  000015000efde4fb565ecce428ffa0bec31879c1666321...
# 2  000015000efde4fb565ecce428ffa0bec31879c1666321...
# 3  000015000efde4fb565ecce428ffa0bec31879c1666321...
# 4  000015000efde4fb565ecce428ffa0bec31879c1666321...
#
#                                         manifest_url  canvas_number  \
# 0  https://digi.ub.uni-heidelberg.de/diglit/iiif/...             16
# 1  https://digi.ub.uni-heidelberg.de/diglit/iiif/...             36
# 2  https://digi.ub.uni-heidelberg.de/diglit/iiif/...             37
# 3  https://digi.ub.uni-heidelberg.de/diglit/iiif/...             44
# 4  https://digi.ub.uni-heidelberg.de/diglit/iiif/...             46
#
#                                            image_url    City  Country  \
# 0  https://digi.ub.uni-heidelberg.de/iiif/2/roczm...  Warsaw   Poland
# 1  https://digi.ub.uni-heidelberg.de/iiif/2/kunst...  Munich  Germany
# 2  https://digi.ub.uni-heidelberg.de/iiif/2/kunst...  Munich  Germany
# 3  https://digi.ub.uni-heidelberg.de/iiif/2/slade...  Kraków   Poland
# 4  https://digi.ub.uni-heidelberg.de/iiif/2/slade...  Kraków   Poland
#
#                                                Title  \
# 0              Rocznik Muzeum Narodowego w Warszawie
# 1                                Die Kunst dem Volke
# 2                                Die Kunst dem Volke
# 3  Studien zur deutschen Kunstgeschichte: Albrech...
# 4  Studien zur deutschen Kunstgeschichte: Albrech...
#
#                                       wkt        Date Journal Type  notice
# 0         POINT(21.011111111111113 52.23)  1972-01-01  Art History     NaN
# 1                   POINT(11.575 48.1375)  1909-01-01  Art Journal     NaN
# 2                   POINT(11.575 48.1375)  1909-01-01  Art Journal     NaN
# 3  POINT(19.937222222222 50.061388888889)  1965-01-01  Art History     NaN
# 4  POINT(19.937222222222 50.061388888889)  1965-01-01  Art History     NaN

# %%
df['Date'] = df['Date'].astype(str) + 'T00:00:00Z'

# %%
df.head(3)
# Out:
#                                       numero_cluster  \
# 0  000015000efde4fb565ecce428ffa0bec31879c1666321...
# 1  000015000efde4fb565ecce428ffa0bec31879c1666321...
# 2  000015000efde4fb565ecce428ffa0bec31879c1666321...
#
#                                         manifest_url  canvas_number  \
# 0  https://digi.ub.uni-heidelberg.de/diglit/iiif/...             16
# 1  https://digi.ub.uni-heidelberg.de/diglit/iiif/...             36
# 2  https://digi.ub.uni-heidelberg.de/diglit/iiif/...             37
#
#                                            image_url    City  Country  \
# 0  https://digi.ub.uni-heidelberg.de/iiif/2/roczm...  Warsaw   Poland
# 1  https://digi.ub.uni-heidelberg.de/iiif/2/kunst...  Munich  Germany
# 2  https://digi.ub.uni-heidelberg.de/iiif/2/kunst...  Munich  Germany
#
#                                    Title                              wkt  \
# 0  Rocznik Muzeum Narodowego w Warszawie  POINT(21.011111111111113 52.23)
# 1                    Die Kunst dem Volke            POINT(11.575 48.1375)
# 2                    Die Kunst dem Volke            POINT(11.575 48.1375)
#
#                    Date Journal Type  notice
# 0  1972-01-01T00:00:00Z  Art History     NaN
# 1  1909-01-01T00:00:00Z  Art Journal     NaN
# 2  1909-01-01T00:00:00Z  Art Journal     NaN

# %%
df = df.drop('notice', axis=1)

# %% [markdown]
# ## Compute pivot

# %% [markdown]
# number of cities and number of type

# %%
pivot_city = pd.pivot_table(df, values='image_url', index='City', aggfunc=pd.Series.nunique)

# %%
pivot_city = pivot_city.rename(columns={"image_url": "City_number"})

# %%
df = pd.merge(df, pivot_city, on=['City'])

# %%
df.head(4)
# Out:
#                                       numero_cluster  \
# 0  000015000efde4fb565ecce428ffa0bec31879c1666321...
# 1  000009001f54dacfe26fde8e4a03c0b31f7943f3fbc378...
# 2  00000600973eda6bfcd054d66af5404f9aa9acb99bbb85...
# 3  00000600973eda6bfcd054d66af5404f9aa9acb99bbb85...
#
#                                         manifest_url  canvas_number  \
# 0  https://digi.ub.uni-heidelberg.de/diglit/iiif/...             16
# 1  https://digi.ub.uni-heidelberg.de/diglit/iiif/...            364
# 2  https://digi.ub.uni-heidelberg.de/diglit/iiif/...              4
# 3  https://digi.ub.uni-heidelberg.de/diglit/iiif/...              9
#
#                                            image_url    City Country  \
# 0  https://digi.ub.uni-heidelberg.de/iiif/2/roczm...  Warsaw  Poland
# 1  https://digi.ub.uni-heidelberg.de/iiif/2/bhs19...  Warsaw  Poland
# 2  https://digi.ub.uni-heidelberg.de/iiif/2/bmusv...  Warsaw  Poland
# 3  https://digi.ub.uni-heidelberg.de/iiif/2/roczm...  Warsaw  Poland
#
#                                     Title                              wkt  \
# 0   Rocznik Muzeum Narodowego w Warszawie  POINT(21.011111111111113 52.23)
# 1                Biuletyn historii sztuki  POINT(21.011111111111113 52.23)
# 2  Bulletin du Musée National de Varsovie  POINT(21.011111111111113 52.23)
# 3   Rocznik Muzeum Narodowego w Warszawie  POINT(21.011111111111113 52.23)
#
#                    Date Journal Type  notice  City_number
# 0  1972-01-01T00:00:00Z  Art History     NaN           19
# 1  1985-01-01T00:00:00Z  Art History     NaN           19
# 2  1984-01-01T00:00:00Z  Art History     NaN           19
# 3  1972-01-01T00:00:00Z  Art History     NaN           19

# %% [markdown]
# ## Kepler Map

# %%
config = {'version': 'v1',
 'config': {'visState': {'filters': [{'dataId': ['Visual Contagions Art'],
     'id': 'gvpk0sjne',
     'name': ['Date'],
     'type': 'timeRange',
     'value': [-2461449600000, -2120631474000],
     'enlarged': True,
     'isAnimating': True,
     'plotType': 'histogram',
     'animationWindow': 'free',
     'yAxis': None,
     'speed': 1}],
   'layers': [{'id': 'gkoo0og',
     'type': 'geojson',
     'config': {'dataId': 'Visual Contagions Art',
      'label': 'Visual Contagions Art',
      'color': [248, 149, 112],
      'highlightColor': [252, 242, 26, 255],
      'columns': {'geojson': 'wkt'},
      'isVisible': True,
      'visConfig': {'opacity': 0.8,
       'strokeOpacity': 0.8,
       'thickness': 0,
       'strokeColor': None,
       'colorRange': {'name': 'Global Warming 4',
        'type': 'sequential',
        'category': 'Uber',
        'colors': ['#FFC300', '#E3611C', '#831A3D', '#5A1846'],
        'reversed': True},
       'strokeColorRange': {'name': 'Global Warming',
        'type': 'sequential',
        'category': 'Uber',
        'colors': ['#5A1846',
         '#900C3F',
         '#C70039',
         '#E3611C',
         '#F1920E',
         '#FFC300']},
       'radius': 10,
       'sizeRange': [0, 10],
       'radiusRange': [20, 45],
       'heightRange': [0, 500],
       'elevationScale': 5,
       'enableElevationZoomFactor': True,
       'stroked': False,
       'filled': True,
       'enable3d': False,
       'wireframe': False},
      'hidden': False,
      'textLabel': [{'field': None,
        'color': [255, 255, 255],
        'size': 18,
        'offset': [0, 0],
        'anchor': 'start',
        'alignment': 'center'}]},
     'visualChannels': {'colorField': {'name': 'City_number',
       'type': 'integer'},
      'colorScale': 'quantile',
      'strokeColorField': None,
      'strokeColorScale': 'quantile',
      'sizeField': None,
      'sizeScale': 'linear',
      'heightField': None,
      'heightScale': 'linear',
      'radiusField': {'name': 'City_number', 'type': 'integer'},
      'radiusScale': 'sqrt'}}],
   'interactionConfig': {'tooltip': {'fieldsToShow': {'Visual Contagions Art': [{'name': 'City',
        'format': None},
       {'name': 'Title', 'format': None},
       {'name': 'image_url', 'format': None},
       {'name': 'Date', 'format': None},
       {'name': 'Country', 'format': None}]},
     'compareMode': False,
     'compareType': 'absolute',
     'enabled': True},
    'brush': {'size': 0.5, 'enabled': False},
    'geocoder': {'enabled': False},
    'coordinate': {'enabled': False}},
   'layerBlending': 'normal',
   'splitMaps': [],
   'animationConfig': {'currentTime': None, 'speed': 1}},
  'mapState': {'bearing': 0,
   'dragRotate': False,
   'latitude': 1.190983988472156,
   'longitude': -21.016067960533633,
   'pitch': 0,
   'zoom': 1.4817269048435613,
   'isSplit': False},
  'mapStyle': {'styleType': 'dark',
   'topLayerGroups': {},
   'visibleLayerGroups': {'label': True,
    'road': True,
    'border': False,
    'building': True,
    'water': True,
    'land': True,
    '3d building': False},
   'threeDBuildingColor': [9.665468314072013,
    17.18305478057247,
    31.1442867897876],
   'mapStyles': {}}}}

# %%
map = KeplerGl(height=600, data={'Visual Contagions Art': df}, config=config)
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter

# %%
map
# Out:
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [{'dataId': ['Visual Contagions Art'], 'i…

# %%
map.save_to_html(data={'Visual Contagions Art': df}, config=config, file_name='VC_Art.html')
# Out:
# Map saved to VC_Art.html!
