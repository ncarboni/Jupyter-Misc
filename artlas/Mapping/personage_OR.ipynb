# %% [markdown]
# # Extract wikidata IDS from Openrefine

# %%
import pandas as pd
import requests
from io import StringIO
import uuid

# %%
url = "http://129.194.213.75/command/core/export-rows"
params = {
    'format': 'csv',
    'project': '2643014612954'
}

response = requests.post(url, params=params)

if response.status_code == 200:
    # Read the content of the response directly into a DataFrame
    df = pd.read_csv(StringIO(response.text), dtype ='str', low_memory=False)
else:
    print(f"Failed to load data. Status code: {response.status_code}")

# %%
df.head()
# Out:
#   id_exhibition_section id_personage wikidata_id       full_name_wd  \
# 0                  3194        37218         NaN  Yannis Manganaris
# 1                  3875        49029         NaN      Lionel Abrams
# 2                  3875        49030         NaN      Walter Batiss
# 3                  3194        37221         NaN      Maurice Farid
# 4                  3194        37222         NaN   Mayez Rizk Ayoub
#
#      no_wd_full_name     id        name first_name membership biography  ...  \
# 0  Yannis Manganaris  33569  Manganaris     Yannis        NaN       NaN  ...
# 1      Lionel Abrams  41584      Abrams     Lionel        NaN       NaN  ...
# 2      Walter Batiss  41585     Battiss     Walter        NaN       NaN  ...
# 3      Maurice Farid  33572       Farid    Maurice        NaN       NaN  ...
# 4   Mayez Rizk Ayoub  33573  Rizk Ayoub      Mayez        NaN       NaN  ...
#
#   country_d x_address_d y_address_d x_city_d y_city_d gender_lower address1  \
# 0       NaN         NaN         NaN      NaN      NaN            m      NaN
# 1       NaN         NaN         NaN      NaN      NaN            m      NaN
# 2       NaN         NaN         NaN      NaN      NaN            m      NaN
# 3       NaN         NaN         NaN      NaN      NaN            m      NaN
# 4       NaN         NaN         NaN      NaN      NaN          NaN      NaN
#
#   id_address1 address2 id_address2
# 0         NaN      NaN         NaN
# 1         NaN      NaN         NaN
# 2         NaN      NaN         NaN
# 3         NaN      NaN         NaN
# 4         NaN      NaN         NaN
#
# [5 rows x 57 columns]

# %%
exhibitor = pd.read_csv("/Users/carboni/Downloads/Personage data.csv",  dtype ='str')

# %%
exhibitor["full_name_wd"] = exhibitor["first_name"] + " " + exhibitor["name"]

# %%
exhibitor.head()
# Out:
#       id        name first_name id_birth_address id_death_address  \
# 0  37218  Manganaris     Yannis            14647              NaN
# 1  49029      Abrams     Lionel              NaN              NaN
# 2  49030     Battiss     Walter              NaN              NaN
# 3  37221       Farid    Maurice            15109              NaN
# 4  37222  Rizk Ayoub      Mayez              NaN              NaN
#
#   id_birth_date id_death_date gender membership notes  ... birth_address  \
# 0          1713           NaN      M        NaN   NaN  ...           NaN
# 1          3097           NaN      M        NaN   NaN  ...           NaN
# 2          1090           NaN      M        NaN   NaN  ...           NaN
# 3          1704           NaN      M        NaN   NaN  ...           NaN
# 4           NaN           NaN    NaN        NaN   NaN  ...           NaN
#
#   death_address id_user_artist biography instructor address1 id_address1  \
# 0           NaN            NaN       NaN        NaN      NaN         NaN
# 1           NaN            NaN       NaN        NaN      NaN         NaN
# 2           NaN            NaN       NaN        NaN      NaN         NaN
# 3           NaN            NaN       NaN        NaN      NaN         NaN
# 4           NaN            NaN       NaN        NaN      NaN         NaN
#
#   address2 id_address2       full_name_wd
# 0      NaN         NaN  Yannis Manganaris
# 1      NaN         NaN      Lionel Abrams
# 2      NaN         NaN     Walter Battiss
# 3      NaN         NaN      Maurice Farid
# 4      NaN         NaN   Mayez Rizk Ayoub
#
# [5 rows x 26 columns]

# %%
df_wiki= df[['id_personage', 'wikidata_id', 'full_name_wd']]

# %%
exhibitor.rename(columns={'id': 'id_personage'}, inplace=True)

# %%
merged_data = exhibitor.merge(df_wiki, on='id_personage', how='left')

# %%
merged_data.head()
# Out:
#   id_personage        name first_name id_birth_address id_death_address  \
# 0        37218  Manganaris     Yannis            14647              NaN
# 1        49029      Abrams     Lionel              NaN              NaN
# 2        49030     Battiss     Walter              NaN              NaN
# 3        37221       Farid    Maurice            15109              NaN
# 4        37222  Rizk Ayoub      Mayez              NaN              NaN
#
#   id_birth_date id_death_date gender membership notes  ... id_user_artist  \
# 0          1713           NaN      M        NaN   NaN  ...            NaN
# 1          3097           NaN      M        NaN   NaN  ...            NaN
# 2          1090           NaN      M        NaN   NaN  ...            NaN
# 3          1704           NaN      M        NaN   NaN  ...            NaN
# 4           NaN           NaN    NaN        NaN   NaN  ...            NaN
#
#   biography instructor address1 id_address1 address2 id_address2  \
# 0       NaN        NaN      NaN         NaN      NaN         NaN
# 1       NaN        NaN      NaN         NaN      NaN         NaN
# 2       NaN        NaN      NaN         NaN      NaN         NaN
# 3       NaN        NaN      NaN         NaN      NaN         NaN
# 4       NaN        NaN      NaN         NaN      NaN         NaN
#
#       full_name_wd_x wikidata_id     full_name_wd_y
# 0  Yannis Manganaris         NaN  Yannis Manganaris
# 1      Lionel Abrams         NaN      Lionel Abrams
# 2     Walter Battiss         NaN      Walter Batiss
# 3      Maurice Farid         NaN      Maurice Farid
# 4   Mayez Rizk Ayoub         NaN   Mayez Rizk Ayoub
#
# [5 rows x 28 columns]

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74579 entries, 0 to 74578
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_personage      74579 non-null  object
#  1   name              74540 non-null  object
#  2   first_name        66428 non-null  object
#  3   id_birth_address  26194 non-null  object
#  4   id_death_address  1214 non-null   object
#  5   id_birth_date     10925 non-null  object
#  6   id_death_date     2909 non-null   object
#  7   gender            59061 non-null  object
#  8   membership        3743 non-null   object
#  9   notes             0 non-null      object
#  10  source            0 non-null      object
#  11  id_type           74579 non-null  object
#  12  id_person         0 non-null      object
#  13  nationality       12885 non-null  object
#  14  id_user           74579 non-null  object
#  15  timestamp         74579 non-null  object
#  16  birth_address     11644 non-null  object
#  17  death_address     666 non-null    object
#  18  id_user_artist    0 non-null      object
#  19  biography         14876 non-null  object
#  20  instructor        564 non-null    object
#  21  address1          17374 non-null  object
#  22  id_address1       42567 non-null  object
#  23  address2          106 non-null    object
#  24  id_address2       382 non-null    object
#  25  full_name_wd_x    66394 non-null  object
#  26  wikidata_id       14859 non-null  object
#  27  full_name_wd_y    47899 non-null  object
# dtypes: object(28)
# memory usage: 16.5+ MB

# %%
merged_data['Full_name'] = merged_data['full_name_wd_y'].combine_first(merged_data['full_name_wd_x'])

# %%
merged_data = merged_data.drop(columns=['full_name_wd_y', 'full_name_wd_x', 'id_user', 'timestamp'])

# %%
def generate_uuid(name):
    name_str = str(name)
    return str(uuid.uuid3(uuid.NAMESPACE_DNS, name_str))

# %%
merged_data['uuid'] = merged_data['Full_name'].apply(generate_uuid)

# %%
merged_data.head()
# Out:
#   id_personage        name first_name id_birth_address id_death_address  \
# 0        37218  Manganaris     Yannis            14647              NaN
# 1        49029      Abrams     Lionel              NaN              NaN
# 2        49030     Battiss     Walter              NaN              NaN
# 3        37221       Farid    Maurice            15109              NaN
# 4        37222  Rizk Ayoub      Mayez              NaN              NaN
#
#   id_birth_date id_death_date gender membership notes  ... id_user_artist  \
# 0          1713           NaN      M        NaN   NaN  ...            NaN
# 1          3097           NaN      M        NaN   NaN  ...            NaN
# 2          1090           NaN      M        NaN   NaN  ...            NaN
# 3          1704           NaN      M        NaN   NaN  ...            NaN
# 4           NaN           NaN    NaN        NaN   NaN  ...            NaN
#
#   biography instructor address1 id_address1 address2 id_address2 wikidata_id  \
# 0       NaN        NaN      NaN         NaN      NaN         NaN         NaN
# 1       NaN        NaN      NaN         NaN      NaN         NaN         NaN
# 2       NaN        NaN      NaN         NaN      NaN         NaN         NaN
# 3       NaN        NaN      NaN         NaN      NaN         NaN         NaN
# 4       NaN        NaN      NaN         NaN      NaN         NaN         NaN
#
#            Full_name                                  uuid
# 0  Yannis Manganaris  7c1dac39-2918-3cf8-bb24-3b9b194edede
# 1      Lionel Abrams  9e34b27c-7a96-32ed-bdf6-f2529ea23675
# 2      Walter Batiss  d859377e-8bc5-3a5b-b3fb-e84c2dca8fcb
# 3      Maurice Farid  2e7ef02a-1e79-3650-bf7e-093cfb853888
# 4   Mayez Rizk Ayoub  0aa3f273-9fbb-30b5-b20f-941cae107f1b
#
# [5 rows x 28 columns]

# %%
columns = merged_data.columns

# Iterate through the columns
for col in columns:
    # Check if the column name contains a space
    if ' ' in col:
        # Replace spaces with underscores
        merged_data.rename(columns={col: col.replace(' ', '_')}, inplace=True)

# %%
merged_data = merged_data.dropna(axis=1, how='all')

# %%
merged_data.to_csv('/Users/carboni/Downloads/uuid_exhibitor.csv', index=False)

# %%
merged_data.to_xml('/Users/carboni/Documents/UNIGE/basart_downloads/2023/data/processed/personage/personage_wd.xml', root_name="data", pretty_print=True, index=False)
