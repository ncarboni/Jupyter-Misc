# %% [markdown]
# # Extract wikidata IDS from Openrefine

# %%
import pandas as pd
import requests
from io import StringIO
import uuid

# %%
url = "http://129.194.213.75/command/core/export-rows"
params = {
    'format': 'csv',
    'project': '2623392316428'
}

response = requests.post(url, params=params)

if response.status_code == 200:
    # Read the content of the response directly into a DataFrame
    df = pd.read_csv(StringIO(response.text), dtype ='str', low_memory=False)
else:
    print(f"Failed to load data. Status code: {response.status_code}")

# %%
df.head()
# Out:
#   id_exhibition_section identity randomINT facet_count id_personage     id  \
# 0                  3194      NaN    320860           2        37218  33569
# 1                  3875      NaN    517062           2        49029  41584
# 2                  3875      NaN    257730           3        49030  41585
# 3                  3194      NaN    792446           4        37221  33572
# 4                  3194      NaN    583494           1        37222  33573
#
#          name first_name          full_name wikidata_id  ... country_d  \
# 0  Manganaris     Yannis  Manganaris Yannis         NaN  ...       NaN
# 1      Abrams     Lionel      Abrams Lionel         NaN  ...       NaN
# 2     Battiss     Walter     Walter Battiss         NaN  ...       NaN
# 3       Farid    Maurice      Farid Maurice         NaN  ...       NaN
# 4  Rizk Ayoub      Mayez   Rizk Ayoub Mayez         NaN  ...       NaN
#
#   x_address_d y_address_d x_city_d y_city_d gender_lower address1 id_address1  \
# 0         NaN         NaN      NaN      NaN            m      NaN         NaN
# 1         NaN         NaN      NaN      NaN            m      NaN         NaN
# 2         NaN         NaN      NaN      NaN            m      NaN         NaN
# 3         NaN         NaN      NaN      NaN            m      NaN         NaN
# 4         NaN         NaN      NaN      NaN          NaN      NaN         NaN
#
#   address2 id_address2
# 0      NaN         NaN
# 1      NaN         NaN
# 2      NaN         NaN
# 3      NaN         NaN
# 4      NaN         NaN
#
# [5 rows x 71 columns]

# %%
exhibitor = pd.read_csv("/Users/carboni/Documents/UNIGE/basart_downloads/2023/data/processed/personage/Exhibitor.csv",  dtype ='str')

# %%
exhibitor["full_name"] = exhibitor["first_name"] + " " + exhibitor["name"]

# %%
exhibitor.head()
# Out:
#   id_exhibition_section id_personage     id        name first_name membership  \
# 0                  3194        37218  33569  Manganaris     Yannis        NaN
# 1                  3875        49029  41584      Abrams     Lionel        NaN
# 2                  3875        49030  41585     Battiss     Walter        NaN
# 3                  3194        37221  33572       Farid    Maurice        NaN
# 4                  3194        37222  33573  Rizk Ayoub      Mayez        NaN
#
#   biography nationality instructor notes  ... x_address_d y_address_d  \
# 0       NaN         NaN        NaN   NaN  ...         NaN         NaN
# 1       NaN         NaN        NaN   NaN  ...         NaN         NaN
# 2       NaN         NaN        NaN   NaN  ...         NaN         NaN
# 3       NaN         NaN        NaN   NaN  ...         NaN         NaN
# 4       NaN         NaN        NaN   NaN  ...         NaN         NaN
#
#   x_city_d y_city_d gender_lower address1 id_address1 address2 id_address2  \
# 0      NaN      NaN            m      NaN         NaN      NaN         NaN
# 1      NaN      NaN            m      NaN         NaN      NaN         NaN
# 2      NaN      NaN            m      NaN         NaN      NaN         NaN
# 3      NaN      NaN            m      NaN         NaN      NaN         NaN
# 4      NaN      NaN          NaN      NaN         NaN      NaN         NaN
#
#            full_name
# 0  Yannis Manganaris
# 1      Lionel Abrams
# 2     Walter Battiss
# 3      Maurice Farid
# 4   Mayez Rizk Ayoub
#
# [5 rows x 55 columns]

# %%
df_wiki= df[['id_personage', 'wikidata_id', 'full_name']]

# %%
merged_data = exhibitor.merge(df_wiki, on='id_personage', how='left', suffixes=('_exhibitor', '_wiki'))

# %%
merged_data.head()
# Out:
#   id_exhibition_section id_personage     id        name first_name membership  \
# 0                  3194        37218  33569  Manganaris     Yannis        NaN
# 1                  3875        49029  41584      Abrams     Lionel        NaN
# 2                  3875        49030  41585     Battiss     Walter        NaN
# 3                  3194        37221  33572       Farid    Maurice        NaN
# 4                  3194        37222  33573  Rizk Ayoub      Mayez        NaN
#
#   biography nationality instructor notes  ... x_city_d y_city_d gender_lower  \
# 0       NaN         NaN        NaN   NaN  ...      NaN      NaN            m
# 1       NaN         NaN        NaN   NaN  ...      NaN      NaN            m
# 2       NaN         NaN        NaN   NaN  ...      NaN      NaN            m
# 3       NaN         NaN        NaN   NaN  ...      NaN      NaN            m
# 4       NaN         NaN        NaN   NaN  ...      NaN      NaN          NaN
#
#   address1 id_address1 address2 id_address2 full_name_exhibitor wikidata_id  \
# 0      NaN         NaN      NaN         NaN   Yannis Manganaris         NaN
# 1      NaN         NaN      NaN         NaN       Lionel Abrams         NaN
# 2      NaN         NaN      NaN         NaN      Walter Battiss         NaN
# 3      NaN         NaN      NaN         NaN       Maurice Farid         NaN
# 4      NaN         NaN      NaN         NaN    Mayez Rizk Ayoub         NaN
#
#       full_name_wiki
# 0  Manganaris Yannis
# 1      Abrams Lionel
# 2     Walter Battiss
# 3      Farid Maurice
# 4   Rizk Ayoub Mayez
#
# [5 rows x 57 columns]

# %%
merged_data['Full_name'] = merged_data['Full_name_y'].combine_first(merged_data['Full_name_x'])

# %%
merged_data["full_name"] = merged_data["first_name"] + " " + merged_data["name"]

# %%
merged_data["full_name"] = merged_data["full_name"].str.strip()

# %%
def generate_uuid(name):
    name_str = str(name)
    return str(uuid.uuid3(uuid.NAMESPACE_DNS, name_str))

# %%
merged_data['uuid'] = merged_data['full_name'].apply(generate_uuid)

# %%
merged_data.head()
# Out:
#   id_exhibition_section id_personage     id        name first_name membership  \
# 0                  3194        37218  33569  Manganaris     Yannis        NaN
# 1                  3875        49029  41584      Abrams     Lionel        NaN
# 2                  3875        49030  41585     Battiss     Walter        NaN
# 3                  3194        37221  33572       Farid    Maurice        NaN
# 4                  3194        37222  33573  Rizk Ayoub      Mayez        NaN
#
#   biography nationality instructor notes  ... x_city_d y_city_d gender_lower  \
# 0       NaN         NaN        NaN   NaN  ...      NaN      NaN            m
# 1       NaN         NaN        NaN   NaN  ...      NaN      NaN            m
# 2       NaN         NaN        NaN   NaN  ...      NaN      NaN            m
# 3       NaN         NaN        NaN   NaN  ...      NaN      NaN            m
# 4       NaN         NaN        NaN   NaN  ...      NaN      NaN          NaN
#
#   address1 id_address1 address2 id_address2 wikidata_id          full_name  \
# 0      NaN         NaN      NaN         NaN         NaN  Yannis Manganaris
# 1      NaN         NaN      NaN         NaN         NaN      Lionel Abrams
# 2      NaN         NaN      NaN         NaN         NaN     Walter Battiss
# 3      NaN         NaN      NaN         NaN         NaN      Maurice Farid
# 4      NaN         NaN      NaN         NaN         NaN   Mayez Rizk Ayoub
#
#                                    uuid
# 0  7c1dac39-2918-3cf8-bb24-3b9b194edede
# 1  9e34b27c-7a96-32ed-bdf6-f2529ea23675
# 2  34153523-e149-3042-95e0-ffcfd816162e
# 3  2e7ef02a-1e79-3650-bf7e-093cfb853888
# 4  0aa3f273-9fbb-30b5-b20f-941cae107f1b
#
# [5 rows x 57 columns]

# %%
columns = merged_data.columns

# Iterate through the columns
for col in columns:
    # Check if the column name contains a space
    if ' ' in col:
        # Replace spaces with underscores
        merged_data.rename(columns={col: col.replace(' ', '_')}, inplace=True)

# %%
merged_data.to_csv('/Users/carboni/uuid_exhibitor.csv', index=False)

# %%
merged_data.to_xml('/Users/carboni/Documents/UNIGE/basart_downloads/2023/data/processed/personage/personage_wd.xml', root_name="data", pretty_print=True)
