# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.ensemble import IsolationForest
import folium
from folium import plugins

# %%
df = pd.read_csv('/Users/carboni/Downloads/Paris_indipendant.csv', low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24176 entries, 0 to 24175
# Data columns (total 85 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Nom artiste                                                               24159 non-null  object
#  1   user                                                                      18126 non-null  object
#  2   Exposition                                                                14342 non-null  object
#  3   Prénom artiste                                                            23687 non-null  object
#  4   Sexe artiste (F/M/FM/vide)                                                24082 non-null  object
#  5   Appartenance à un groupe                                                  2961 non-null   object
# ...

# %%
df.head()
# Out:
#   Nom artiste      user                                         Exposition  \
# 0       ABBAL  disanto7  Exposition du cinquantenaire de la Société des...
# 1       ABBAL  disanto7  Exposition du cinquantenaire de la Société des...
# 2   ABONDANCE  disanto7  Exposition du cinquantenaire de la Société des...
# 3   ABONDANCE  disanto7  Exposition du cinquantenaire de la Société des...
# 4        ABOU  disanto7  Exposition du cinquantenaire de la Société des...
#
#   Prénom artiste Sexe artiste (F/M/FM/vide) Appartenance à un groupe  \
# 0          André                          M
# 1          André                          M
# 2        Maurice                          M
# 3        Maurice                          M
# 4      Albert-H.                          M
#
#           Éléments biographiques  \
# 0  1920. né à Moissac (T.-et-G.)
# 1  1920. né à Moissac (T.-et-G.)
# 2                né à Paris 1934
# 3                né à Paris 1934
# 4            1929 né à Marseille
#
# ...

# %%
def generateBaseMap(default_location=[48.8589465, 2.2768234,12], default_zoom_start=12):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

base_map = generateBaseMap
base_map

from folium.plugins import HeatMap
base_map = generateBaseMap()
HeatMap(data=df[['lat', 'lng']].groupby(['lng']).sum().reset_index().values.tolist(), radius=8, max_zoom=13).add_to(base_map)

base_map.add_child(folium.ClickForMarker(popup='Potential Location'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 9>()
#       6 base_map
#       8 from folium.plugins import HeatMap
# ----> 9 base_map = generateBaseMap()
#      10 HeatMap(data=df[['lat', 'lng']].groupby(['lng']).sum().reset_index().values.tolist(), radius=8, max_zoom=13).add_to(base_map)
#      12 base_map.add_child(folium.ClickForMarker(popup='Potential Location'))
#
# Input In [8], in generateBaseMap(default_location, default_zoom_start)
#       1 def generateBaseMap(default_location=[48.8589465, 2.2768234,12], default_zoom_start=12):
# ----> 2     base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
#       3     return base_map
#
# ...
