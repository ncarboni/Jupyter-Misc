# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/carboni/Downloads/Leopard.csv')

# %% [markdown]
# ### In case of clusters of other keywords + wkt

# %%
df_sort = df.sort_values(['Cluster', 'Date'], ascending=[True, True])

# %%
df_sort.to_csv('leopard_sort.csv', index=False)

# %%
transformed_data = []

for cluster, group_df in df.groupby('Cluster'):
    group_df = group_df.sort_values(by='Date')
    group_df['origin'] = group_df['wkt']
    group_df['destination'] = group_df['wkt'].shift(-1).fillna(group_df['wkt'].iloc[-1])
    transformed_data.append(group_df)

# Concatenate all transformed groups
transformed_df = pd.concat(transformed_data)

# %%
transformed_df.head()

# %% [markdown]
# ### In case of clusters of other keywords + wkt

# %%
transformed_data = []

for cluster, group_df in df.groupby('Cluster'):
    group_df = group_df.sort_values(by='Date')
    
    cross_joined_df = group_df.merge(group_df, how='cross', suffixes=('_origin', '_destination'))

    cross_joined_df = cross_joined_df[cross_joined_df['Date_destination'] > cross_joined_df['Date_origin']]
    transformed_data.append(cross_joined_df)

# Concatenate all transformed groups
transformed_df = pd.concat(transformed_data)

# %%
transformed_df
# Out:
#              Cluster_origin  \
# 1        Bête Seule (Tigre)
# 2        Bête Seule (Tigre)
# 3        Bête Seule (Tigre)
# 4        Bête Seule (Tigre)
# 5        Bête Seule (Tigre)
# ..                      ...
# 925  Fourrure / Habit Tigre
# 926  Fourrure / Habit Tigre
# 927  Fourrure / Habit Tigre
# 959  Fourrure / Habit Tigre
# 991  Fourrure / Habit Tigre
#
#                                    manifest_url_origin  canvas_number_origin  \
# 1    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k19...                 422.0
# 2    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k19...                 422.0
# 3    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k19...                 422.0
# 4    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k19...                 422.0
# 5    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k19...                 422.0
# ..                                                 ...                   ...
# 925   https://iiif.unige.ch/dhportal/ug643818/manifest                  16.0
# 926   https://iiif.unige.ch/dhportal/ug643818/manifest                  16.0
# 927   https://iiif.unige.ch/dhportal/ug643818/manifest                  16.0
# 959   https://iiif.unige.ch/dhportal/ug755042/manifest                  66.0
# 991   https://iiif.unige.ch/dhportal/ug755042/manifest                  66.0
#
#                                       image_url_origin       City_origin  \
# 1    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k19...             Paris
# 2    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k19...             Paris
# 3    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k19...             Paris
# 4    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k19...             Paris
# 5    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k19...             Paris
# ..                                                 ...               ...
# 925  https://iiif.unige.ch/iiif/2/visualcontagions/...  Washington, D.C.
# 926  https://iiif.unige.ch/iiif/2/visualcontagions/...  Washington, D.C.
# 927  https://iiif.unige.ch/iiif/2/visualcontagions/...  Washington, D.C.
# 959  https://iiif.unige.ch/iiif/2/visualcontagions/...  Washington, D.C.
# 991  https://iiif.unige.ch/iiif/2/visualcontagions/...  Washington, D.C.
#
#                Country_origin  \
# 1                      France
# 2                      France
# 3                      France
# 4                      France
# 5                      France
# ..                        ...
# 925  United States of America
# 926  United States of America
# 927  United States of America
# 959  United States of America
# 991  United States of America
#
#                                           Title_origin  \
# 1    L'Artiste : journal de la littérature et des b...
# 2    L'Artiste : journal de la littérature et des b...
# 3    L'Artiste : journal de la littérature et des b...
# 4    L'Artiste : journal de la littérature et des b...
# 5    L'Artiste : journal de la littérature et des b...
# ..                                                 ...
# 925                        National Geographic Society
# 926                        National Geographic Society
# 927                        National Geographic Society
# 959                        National Geographic Society
# 991                        National Geographic Society
#
#                                  wkt_origin Date_origin Journal Type_origin  \
# 1    POINT(2.3513888888889 48.856944444444)  1831-07-10         Art History
# 2    POINT(2.3513888888889 48.856944444444)  1831-07-10         Art History
# 3    POINT(2.3513888888889 48.856944444444)  1831-07-10         Art History
# 4    POINT(2.3513888888889 48.856944444444)  1831-07-10         Art History
# 5    POINT(2.3513888888889 48.856944444444)  1831-07-10         Art History
# ..                                      ...         ...                 ...
# 925          POINT(-77.036666666667 38.895)  1997-12-01           Geography
# 926          POINT(-77.036666666667 38.895)  1997-12-01           Geography
# 927          POINT(-77.036666666667 38.895)  1997-12-01           Geography
# 959          POINT(-77.036666666667 38.895)  2014-01-01           Geography
# 991          POINT(-77.036666666667 38.895)  2014-01-01           Geography
#
#      ...                           manifest_url_destination  \
# 1    ...  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k19...
# 2    ...  https://iiif.unige.ch/dhportal/ug27806292/mani...
# 3    ...  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k22...
# 4    ...  https://iiif.archive.org/iiif/sim_illustrated-...
# 5    ...  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k62...
# ..   ...                                                ...
# 925  ...   https://iiif.unige.ch/dhportal/ug755042/manifest
# 926  ...   https://iiif.unige.ch/dhportal/ug755042/manifest
# 927  ...  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 959  ...  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 991  ...  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
#
#     canvas_number_destination  \
# 1                       412.0
# 2                       320.0
# 3                       139.0
# 4                        23.0
# 5                        11.0
# ..                        ...
# 925                      66.0
# 926                      66.0
# 927                      83.0
# 959                      83.0
# 991                      83.0
#
#                                  image_url_destination  City_destination  \
# 1    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k19...             Paris
# 2    https://iiif.unige.ch/iiif/2/fedora_ug27812760...          New York
# 3    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k22...             Paris
# 4    https://iiif.archive.org/image/iiif/3/sim_illu...            London
# 5    https://gallica.bnf.fr/iiif/ark:/12148/bpt6k62...             Paris
# ..                                                 ...               ...
# 925  https://iiif.unige.ch/iiif/2/visualcontagions/...  Washington, D.C.
# 926  https://iiif.unige.ch/iiif/2/visualcontagions/...  Washington, D.C.
# 927  https://digi.ub.uni-heidelberg.de/iiif/2/sew_b...            Warsaw
# 959  https://digi.ub.uni-heidelberg.de/iiif/2/sew_b...            Warsaw
# 991  https://digi.ub.uni-heidelberg.de/iiif/2/sew_b...            Warsaw
#
#           Country_destination  \
# 1                      France
# 2    United States of America
# 3                      France
# 4              United Kingdom
# 5                      France
# ..                        ...
# 925  United States of America
# 926  United States of America
# 927                    Poland
# 959                    Poland
# 991                    Poland
#
#                                      Title_destination  \
# 1    L'Artiste : journal de la littérature et des b...
# 2                      The Illustrated Magazine of Art
# 3    L'Artiste : journal de la littérature et des b...
# 4    The Illustrated London News 1859-05-07: Vol 34...
# 5                             Le Monde illustré (1857)
# ..                                                 ...
# 925                        National Geographic Society
# 926                        National Geographic Society
# 927  Sztuka Europy Wschodniej / The Art of Eastern ...
# 959  Sztuka Europy Wschodniej / The Art of Eastern ...
# 991  Sztuka Europy Wschodniej / The Art of Eastern ...
#
#                             wkt_destination Date_destination  \
# 1    POINT(2.3513888888889 48.856944444444)       1832-07-10
# 2               POINT(-74.006015 40.712728)       1854-01-01
# 3    POINT(2.3513888888889 48.856944444444)       1856-07-10
# 4            POINT(-0.1275 51.507222222222)       1859-05-07
# 5    POINT(2.3513888888889 48.856944444444)       1863-04-04
# ..                                      ...              ...
# 925          POINT(-77.036666666667 38.895)       2014-01-01
# 926          POINT(-77.036666666667 38.895)       2014-01-01
# 927         POINT(21.011111111111113 52.23)       2017-01-01
# 959         POINT(21.011111111111113 52.23)       2017-01-01
# 991         POINT(21.011111111111113 52.23)       2017-01-01
#
#     Journal Type_destination Unnamed: 10_destination
# 1                Art History                     NaN
# 2                Art Journal                     NaN
# 3                Art History                     NaN
# 4                       News                     NaN
# 5           Culture, Leisure                     NaN
# ..                       ...                     ...
# 925                Geography                     NaN
# 926                Geography                     NaN
# 927              Art History                     NaN
# 959              Art History                     NaN
# 991              Art History                     NaN
#
# [957685 rows x 22 columns]

# %%
transformed_data = []

for cluster, group_df in df.groupby('Cluster'):
    group_df = group_df.sort_values(by='Date')
    group_df['coord'] = group_df['lat'] + ", " + group_df['long']
    group_df['origin'] = group_df['coord']
    group_df['destination'] = group_df['coord'].shift(-1).fillna(group_df['wkt'].iloc[-1])
    transformed_data.append(group_df)

# Concatenate all transformed groups
transformed_df = pd.concat(transformed_data)

# %% [markdown]
# ### Without cluster but with coordinates

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values(by='Date')

# %%
df['origin_lat'] = df['lat']
df['origin_long'] = df['long']

# %%
df['dest_lat'] = df['lat'].shift(-1).fillna(df['lat'].iloc[-1])
df['dest_long'] = df['long'].shift(-1).fillna(df['long'].iloc[-1])

# %% [markdown]
# ### Common Operations

# %%
transformed_df['Date'] = pd.to_datetime(transformed_df['Date']).dt.strftime('%Y-%m-%dT%H:%M:%S')

# %%
transformed_df[['origin_longitude', 'origin_latitude']] = transformed_df['origin'].str.extract(r'POINT\(([^ ]+) ([^ ]+)\)')

# %%
transformed_df[['destination_longitude', 'destination_latitude']] = transformed_df['destination'].str.extract(r'POINT\(([^ ]+) ([^ ]+)\)')

# %%
transformed_df.drop(['destination', 'origin', 'wkt'], axis=1, inplace=True)

# %%
# Calculate the duration for each movement
transformed_df['Date'] = pd.to_datetime(transformed_df['Date'])
transformed_df['Duration'] = transformed_df.groupby('Cluster')['Date'].diff().fillna(pd.Timedelta(seconds=0))

# %% [markdown]
# ### Only for Leopard data

# %%
transformed_df['City'] = transformed_df['City'].replace('New York', 'New York City')

# %% [markdown]
# ### Count cities and transform dates in datetime

# %%
transformed_df['city_number'] = transformed_df.groupby(['City'])['City'].transform('count')

# %%
transformed_df['Date'] = pd.to_datetime(transformed_df['Date']).dt.strftime('%Y-%m-%dT%H:%M:%S')

# %%
transformed_df.to_csv('foursquare_mult.csv', index=False)
